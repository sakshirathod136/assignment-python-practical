# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshirathod136/assignment-python-practical/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Even numbers from 1 to 10:")

for i in range(1, 11):
    if i % 2 == 0:
        print(i)
# Out:
# Even numbers from 1 to 10:
# 2
# 4
# 6
# 8
# 10
