# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshirathod136/assignment-python-practical/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d = {'a': 3, 'b': 1, 'c': 2}

asc = dict(sorted(d.items(), key=lambda x: x[1]))
desc = dict(sorted(d.items(), key=lambda x: x[1], reverse=True))

print("Ascending:", asc)
print("Descending:", desc)
# Out:
# Ascending: {'b': 1, 'c': 2, 'a': 3}
# Descending: {'a': 3, 'c': 2, 'b': 1}

# %%
d = {'name': 'sakshi', 'age': 20}

key = 'age'

if key in d:
    print("Key exists")
else:
    print("Key not found")
# Out:
# Key exists

# %%
d1 = {'a': 1, 'b': 2}
d2 = {'c': 3, 'd': 4}

d1.update(d2)
print(d1)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
t = (1, 2, 3)

t = t + (4,)
print(t)
# Out:
# (1, 2, 3, 4)

# %%
t = (10, "Hello", 3.5, True)

print(t)
# Out:
# (10, 'Hello', 3.5, True)

# %%
list1 = [10, 20, 30, 40]

print("Sum =", sum(list1))
# Out:
# Sum = 100

# %%
list1 = [10, 50, 30, 80, 40]

print("Largest =", max(list1))
# Out:
# Largest = 80

# %%
s = {1, 2, 3}

s.add(4)
s.update([5, 6])

print(s)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
from array import *

arr = array('i', [1, 2, 3, 4, 5])

arr.reverse()
print(arr)
# Out:
# array('i', [5, 4, 3, 2, 1])

# %%
from array import *

arr = array('i', [10, 20, 30, 40, 50])

for i in arr:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50
