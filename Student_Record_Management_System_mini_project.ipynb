# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshirathod136/assignment-python-practical/blob/main/Student_Record_Management_System_mini_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
students = {}

while True:
    print("\n===== STUDENT RECORD MANAGEMENT SYSTEM =====")
    print("1. Add Student")
    print("2. View Students")
    print("3. Search Student")
    print("4. Update Student")
    print("5. Delete Student")
    print("6. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        roll = input("Enter Roll Number: ")
        name = input("Enter Name: ")
        marks = input("Enter Marks: ")

        students[roll] = {
            "Name": name,
            "Marks": marks
        }

        print("Student Added Successfully!")

    elif choice == "2":
        if len(students) == 0:
            print("No Records Found")
        else:
            for roll, details in students.items():
                print("Roll:", roll)
                print("Name:", details["Name"])
                print("Marks:", details["Marks"])
                print("----------------")

    elif choice == "3":
        roll = input("Enter Roll Number: ")

        if roll in students:
            print(students[roll])
        else:
            print("Student Not Found")

    elif choice == "4":
        roll = input("Enter Roll Number: ")

        if roll in students:
            students[roll]["Name"] = input("Enter New Name: ")
            students[roll]["Marks"] = input("Enter New Marks: ")
            print("Record Updated")
        else:
            print("Student Not Found")

    elif choice == "5":
        roll = input("Enter Roll Number: ")

        if roll in students:
            del students[roll]
            print("Record Deleted")
        else:
            print("Student Not Found")

    elif choice == "6":
        print("Thank You")
        break

    else:
        print("Invalid Choice")
