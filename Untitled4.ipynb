# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshirathod136/assignment-python-practical/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str1 = "Hello World"

length = len(str1)
print("Length of string is:", length)
# Out:
# Length of string is: 11

# %%
str1 = "Python"

if len(str1) < 2:
    print("Empty String")
else:
    new_str = str1[:2] + str1[-2:]
    print("New string:", new_str)
# Out:
# New string: Pyon

# %%
str1 = "Hello"
str2 = "World"

result = str1 + str2
print("Concatenated string:", result)
# Out:
# Concatenated string: HelloWorld
