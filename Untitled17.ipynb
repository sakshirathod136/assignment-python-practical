# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshirathod136/assignment-python-practical/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sum = 0

for i in range(1, 11):
    if i % 2 != 0:
        sum += i

print("Sum of odd numbers from 1 to 10:", sum)
# Out:
# Sum of odd numbers from 1 to 10: 25
